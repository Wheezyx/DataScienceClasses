# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

print("Funkcja liniowa, kwadratowa, trzeciego rzędu")
x = np.linspace(0, 2, 50)

plt.plot(x, x, label='linear')
plt.plot(x, x**2, label='quadratic')
plt.plot(x, x**3, label='cubic')

plt.xlabel('x')
plt.ylabel('y')
plt.legend()

plt.show()
# Out:
# Funkcja liniowa, kwadratowa, trzeciego rzędu

# %%
print("Cosinus")
x = np.arange(0,4*np.pi,0.1)   # start,stop,step
y = np.sin(x)
plt.plot(x,y)
plt.show()
# Out:
# Cosinus

# %%
cars = pd.read_csv('samochody1tys.csv')

# %%
print('Pogrupowanie względem marki, zliczenie oraz utworzenie wykresu słupkowego')
plot = cars.groupby('marka')['marka'].count().sort_values().plot.bar(figsize=(15, 15))
plot.set_ylabel('Ilosc')
# Out:
# Pogrupowanie względem marki, zliczenie oraz utworzenie wykresu słupkowego
# Text(0, 0.5, 'Ilosc')

# %%
print('Grupowanie po roku produkcji, zliczenie i wykreślenie wykresy kołowego.')
cars.groupby('rok_produkcji')['rok_produkcji'].count().plot.pie(figsize=(15, 15), legend=True, autopct='%1.1f%%')
# Out:
# Grupowanie po roku produkcji, zliczenie i wykreślenie wykresy kołowego.

# %%
ax = cars.hist(column='rok_produkcji', bins=25, grid=True, figsize=(15,15), layout=(4,1), sharex=True, color='#86bf91', zorder=1, rwidth=1.3)
