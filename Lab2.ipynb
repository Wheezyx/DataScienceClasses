# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
cars = pd.read_csv("samochody1tys.csv")

# %%
s = pd.Series([1,np.nan,6,8])
s
# Out:
# 0    1.0
# 1    NaN
# 2    6.0
# 3    8.0
# dtype: float64

# %%
dates = pd.date_range('20140101', periods=6)
df = pd.DataFrame(np.random.randn(6,4), index= dates)
df
# Out:
#                    0         1         2         3
# 2014-01-01  0.524489 -0.757541 -0.861493 -1.118182
# 2014-01-02 -2.204880 -0.250087 -0.706773 -0.780935
# 2014-01-03  0.203486  1.464006  1.043755 -0.771451
# 2014-01-04  0.035649  0.846043 -1.813855  1.197930
# 2014-01-05 -1.041265  2.174071 -0.946376  2.372538
# 2014-01-06 -0.308477  0.460663 -1.521749  0.129772

# %%
cars.head()
# Out:
#    id       marka        model  rok_produkcji rodzaj_silnika  \
# 0   0      Nissan  X-Trail III         2014.0         Diesel
# 1   1         BMW       X1 E84         2012.0         Diesel
# 2   2        Opel     Zafira A         2004.0    Benzyna+CNG
# 3   3     Hyundai        i10 I         2008.0        Benzyna
# 4   4  Volkswagen           CC         2010.0         Diesel
#
#    pojemnosc_silnika  przebieg     cena     wojewodztwo
# 0             1600.0  160000.0  75900.0    Dolnośląskie
# 1             2000.0  149000.0  70900.0  Świętokrzyskie
# 2             1600.0   99000.0   9800.0        Opolskie
# 3             1100.0   93000.0  11900.0         Łódzkie
# 4             1968.0  127428.0  49900.0   Wielkopolskie

# %%
cars.tail(3)
# Out:
#       id    marka    model  rok_produkcji rodzaj_silnika  pojemnosc_silnika  \
# 997  997  Renault    Modus         2004.0        Benzyna             1200.0
# 998  998     Audi    A3 8L         2000.0        Benzyna             1595.0
# 999  999    Volvo  XC 60 I         2016.0         Diesel             1969.0
#
#      przebieg      cena  wojewodztwo
# 997  168111.0   10900.0      Łódzkie
# 998  226500.0    5400.0  Małopolskie
# 999   13617.0  136900.0  Małopolskie

# %%
cars.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
cars.columns
# Out:
# Index(['id', 'marka', 'model', 'rok_produkcji', 'rodzaj_silnika',
#        'pojemnosc_silnika', 'przebieg', 'cena', 'wojewodztwo'],
#       dtype='object')

# %%
cars.to_numpy()
# Out:
# array([[0, 'Nissan', 'X-Trail III', ..., 160000.0, 75900.0,
#         'Dolnośląskie'],
#        [1, 'BMW', 'X1 E84', ..., 149000.0, 70900.0, 'Świętokrzyskie'],
#        [2, 'Opel', 'Zafira A', ..., 99000.0, 9800.0, 'Opolskie'],
#        ...,
#        [997, 'Renault', 'Modus', ..., 168111.0, 10900.0, 'Łódzkie'],
#        [998, 'Audi', 'A3 8L', ..., 226500.0, 5400.0, 'Małopolskie'],
#        [999, 'Volvo', 'XC 60 I', ..., 13617.0, 136900.0, 'Małopolskie']],
#       dtype=object)

# %%
cars.describe()
# Out:
#                 id  rok_produkcji  pojemnosc_silnika       przebieg  \
# count  1000.000000    1000.000000        1000.000000    1000.000000
# mean    499.500000    2009.009000        2040.065000  132556.677000
# std     288.819436       5.907946        6014.545066   90094.944138
# min       0.000000    1979.000000           1.000000       1.000000
# 25%     249.750000    2005.000000        1500.000000   51750.000000
# 50%     499.500000    2009.000000        1800.000000  149000.000000
# 75%     749.250000    2014.000000        2000.000000  193000.000000
# max     999.000000    2017.000000      191000.000000  647000.000000
#
#                 cena
# count    1000.000000
# mean    51942.181000
# std     70057.918015
# min       650.000000
# 25%     14900.000000
# 50%     27250.000000
# 75%     58900.000000
# max    616000.000000

# %%
cars.T
# Out:
#                             0               1            2        3    \
# id                            0               1            2        3
# marka                    Nissan             BMW         Opel  Hyundai
# model               X-Trail III          X1 E84     Zafira A    i10 I
# rok_produkcji              2014            2012         2004     2008
# rodzaj_silnika           Diesel          Diesel  Benzyna+CNG  Benzyna
# pojemnosc_silnika          1600            2000         1600     1100
# przebieg                 160000          149000        99000    93000
# cena                      75900           70900         9800    11900
# wojewodztwo        Dolnośląskie  Świętokrzyskie     Opolskie  Łódzkie
#
#                              4            5             6          7    \
# id                             4            5             6          7
# marka                 Volkswagen         Fiat        Nissan       Seat
# ...

# %%
cars.sort_index(axis=1, ascending=False)
# Out:
#         wojewodztwo  rok_produkcji rodzaj_silnika  przebieg  \
# 0      Dolnośląskie         2014.0         Diesel  160000.0
# 1    Świętokrzyskie         2012.0         Diesel  149000.0
# 2          Opolskie         2004.0    Benzyna+CNG   99000.0
# 3           Łódzkie         2008.0        Benzyna   93000.0
# 4     Wielkopolskie         2010.0         Diesel  127428.0
# ..              ...            ...            ...       ...
# 995     Małopolskie         2009.0         Diesel  182000.0
# 996       Lubelskie         2012.0        Benzyna   42700.0
# 997         Łódzkie         2004.0        Benzyna  168111.0
# 998     Małopolskie         2000.0        Benzyna  226500.0
# 999     Małopolskie         2016.0         Diesel   13617.0
#
#      pojemnosc_silnika        model       marka   id      cena
# 0               1600.0  X-Trail III      Nissan    0   75900.0
# 1               2000.0       X1 E84         BMW    1   70900.0
# ...

# %%
cars.sort_values(by="wojewodztwo")
# Out:
#       id       marka                 model  rok_produkcji rodzaj_silnika  \
# 0      0      Nissan           X-Trail III         2014.0         Diesel
# 126  126  Land Rover  Range Rover Sport II         2017.0         Diesel
# 848  848  Volkswagen             Golf Plus         2005.0         Diesel
# 119  119       Škoda            Octavia II         2010.0         Diesel
# 852  852     Citroën    C4 Grand Picasso I         2008.0         Diesel
# ..   ...         ...                   ...            ...            ...
# 144  144        Audi                 Q5 8R         2015.0         Diesel
# 34    34     Citroën              Xsara II         2002.0        Benzyna
# 816  816      Jaguar                X-Type         2004.0         Diesel
# 708  708       Volvo                V70 II         2003.0        Benzyna
# 268  268         BMW                X3 E83         2009.0         Diesel
#
#      pojemnosc_silnika  przebieg      cena     wojewodztwo
# ...

# %%
cars['cena']
# Out:
# 0       75900.0
# 1       70900.0
# 2        9800.0
# 3       11900.0
# 4       49900.0
#          ...
# 995     33900.0
# 996     25400.0
# 997     10900.0
# 998      5400.0
# 999    136900.0
# Name: cena, Length: 1000, dtype: float64

# %%
cars[0:3]
# Out:
#    id   marka        model  rok_produkcji rodzaj_silnika  pojemnosc_silnika  \
# 0   0  Nissan  X-Trail III         2014.0         Diesel             1600.0
# 1   1     BMW       X1 E84         2012.0         Diesel             2000.0
# 2   2    Opel     Zafira A         2004.0    Benzyna+CNG             1600.0
#
#    przebieg     cena     wojewodztwo
# 0  160000.0  75900.0    Dolnośląskie
# 1  149000.0  70900.0  Świętokrzyskie
# 2   99000.0   9800.0        Opolskie

# %%
cars.loc[:, ['model','rodzaj_silnika']]
# Out:
#            model rodzaj_silnika
# 0    X-Trail III         Diesel
# 1         X1 E84         Diesel
# 2       Zafira A    Benzyna+CNG
# 3          i10 I        Benzyna
# 4             CC         Diesel
# ..           ...            ...
# 995          159         Diesel
# 996     Fabia II        Benzyna
# 997        Modus        Benzyna
# 998        A3 8L        Benzyna
# 999      XC 60 I         Diesel
#
# [1000 rows x 2 columns]

# %%
cars.loc[50:100,['model','rodzaj_silnika']]
# Out:
#              model rodzaj_silnika
# 50        Scenic I         Diesel
# 51           A6 C6         Diesel
# 52         Clubman         Diesel
# 53     Seria 5 F10         Diesel
# 54     Seria 3 E90        Benzyna
# 55      Mondeo Mk4         Diesel
# 56      Insignia A         Diesel
# 57         Polo IV        Benzyna
# 58       Focus Mk3        Benzyna
# 59           307 I        Benzyna
# 60           Q7 II         Diesel
# 61           A8 D3    Benzyna+LPG
# 62         Corsa D        Benzyna
# 63             207        Benzyna
# 64       Laguna II         Diesel
# 65    Klasa C W204         Diesel
# 66     Seria 5 F10         Diesel
# 67      Mondeo Mk4         Diesel
# 68     Trans Sport    Benzyna+LPG
# 69          Cougar        Benzyna
# 70        Leon III        Benzyna
# 71     X-Trail III         Diesel
# 72             V90         Diesel
# 73          C5 III         Diesel
# 74        Zafira B         Diesel
# 75        RAV4 III         Diesel
# ...

# %%
cars.loc[50,['model','rodzaj_silnika']]
# Out:
# model             Scenic I
# rodzaj_silnika      Diesel
# Name: 50, dtype: object

# %%
cars.iloc[562]
# Out:
# id                                  562
# marka                            Suzuki
# model                   Grand Vitara II
# rok_produkcji                      2006
# rodzaj_silnika                  Benzyna
# pojemnosc_silnika                  1995
# przebieg                         138000
# cena                              27900
# wojewodztwo          Zachodniopomorskie
# Name: 562, dtype: object

# %%
cars.iloc[3:10, 2:4]
# Out:
#        model  rok_produkcji
# 3      i10 I         2008.0
# 4         CC         2010.0
# 5        500         2014.0
# 6  X-Trail I         2004.0
# 7  Toledo II         2000.0
# 8         CC         2014.0
# 9       Juke         2016.0

# %%
cars.iloc[[1, 2, 4], [0, 2]]
# Out:
#    id     model
# 1   1    X1 E84
# 2   2  Zafira A
# 4   4        CC

# %%
cars.iloc[1:3, :]
# Out:
#    id marka     model  rok_produkcji rodzaj_silnika  pojemnosc_silnika  \
# 1   1   BMW    X1 E84         2012.0         Diesel             2000.0
# 2   2  Opel  Zafira A         2004.0    Benzyna+CNG             1600.0
#
#    przebieg     cena     wojewodztwo
# 1  149000.0  70900.0  Świętokrzyskie
# 2   99000.0   9800.0        Opolskie

# %%
cars.iloc[: , 1:3]
# Out:
#           marka        model
# 0        Nissan  X-Trail III
# 1           BMW       X1 E84
# 2          Opel     Zafira A
# 3       Hyundai        i10 I
# 4    Volkswagen           CC
# ..          ...          ...
# 995  Alfa Romeo          159
# 996       Škoda     Fabia II
# 997     Renault        Modus
# 998        Audi        A3 8L
# 999       Volvo      XC 60 I
#
# [1000 rows x 2 columns]

# %%
cars[cars.rok_produkcji > 2016]
# Out:
#       id          marka         model  rok_produkcji rodzaj_silnika  \
# 17    17  Mercedes-Benz  Klasa E W213         2017.0         Diesel
# 18    18     Volkswagen     Tiguan II         2017.0         Diesel
# 20    20          Honda       CR-V IV         2017.0        Benzyna
# 21    21  Mercedes-Benz  Klasa E W213         2017.0         Diesel
# 32    32         Suzuki   SX4 S-Cross         2017.0        Benzyna
# ..   ...            ...           ...            ...            ...
# 967  967           Audi         A6 C7         2017.0         Diesel
# 985  985           Fiat           500         2017.0        Benzyna
# 988  988            BMW            M2         2017.0        Benzyna
# 992  992        Renault       Clio IV         2017.0        Benzyna
# 993  993           Fiat       Tipo II         2017.0        Benzyna
#
#      pojemnosc_silnika  przebieg      cena          wojewodztwo
# 17              1950.0       5.0  258709.0              Łódzkie
# ...

# %%
cars[cars['marka'].isin(['Nissan'])]
# Out:
#       id   marka        model  rok_produkcji rodzaj_silnika  \
# 0      0  Nissan  X-Trail III         2014.0         Diesel
# 6      6  Nissan    X-Trail I         2004.0         Diesel
# 9      9  Nissan         Juke         2016.0        Benzyna
# 42    42  Nissan   Qashqai II         2017.0        Benzyna
# 71    71  Nissan  X-Trail III         2017.0         Diesel
# 77    77  Nissan    Qashqai+2         2009.0        Benzyna
# 135  135  Nissan    Qashqai I         2013.0         Diesel
# 181  181  Nissan   Almera N16         2006.0        Benzyna
# 262  262  Nissan      Note II         2013.0        Benzyna
# 307  307  Nissan         Juke         2012.0        Benzyna
# 407  407  Nissan   Terrano II         2001.0         Diesel
# 448  448  Nissan         Juke         2010.0        Benzyna
# 472  472  Nissan   Qashqai II         2017.0         Diesel
# 576  576  Nissan  Primera P12         2003.0         Diesel
# 577  577  Nissan    X-Trail I         2003.0        Benzyna
# ...

# %%
s1 = pd.Series([1, 2, 3, 4, 5, 6], index=pd.date_range('20130102', periods=6))

# %%
df.at[dates[0], 'A'] = 0
df.iat[0, 1] = 0
df.loc[:, 'D'] = np.array([5] * len(df))
df
# Out:
#                    0         1         2         3    A  D
# 2014-01-01  0.524489  0.000000 -0.861493 -1.118182  0.0  5
# 2014-01-02 -2.204880 -0.250087 -0.706773 -0.780935  NaN  5
# 2014-01-03  0.203486  1.464006  1.043755 -0.771451  NaN  5
# 2014-01-04  0.035649  0.846043 -1.813855  1.197930  NaN  5
# 2014-01-05 -1.041265  2.174071 -0.946376  2.372538  NaN  5
# 2014-01-06 -0.308477  0.460663 -1.521749  0.129772  NaN  5

# %%
df1 = df.reindex(index=dates[0:4], columns=list(df.columns) + ['E'])
df1.loc[dates[0]:dates[1], 'E'] = 1
df1
# Out:
#                    0         1         2         3    A  D    E
# 2014-01-01  0.524489  0.000000 -0.861493 -1.118182  0.0  5  1.0
# 2014-01-02 -2.204880 -0.250087 -0.706773 -0.780935  NaN  5  1.0
# 2014-01-03  0.203486  1.464006  1.043755 -0.771451  NaN  5  NaN
# 2014-01-04  0.035649  0.846043 -1.813855  1.197930  NaN  5  NaN

# %%
df1.dropna(how='any')
# Out:
#                    0    1         2         3    A  D    E
# 2014-01-01  0.524489  0.0 -0.861493 -1.118182  0.0  5  1.0

# %%
df1.fillna(value=5)
# Out:
#                    0         1         2         3    A  D    E
# 2014-01-01  0.524489  0.000000 -0.861493 -1.118182  0.0  5  1.0
# 2014-01-02 -2.204880 -0.250087 -0.706773 -0.780935  5.0  5  1.0
# 2014-01-03  0.203486  1.464006  1.043755 -0.771451  5.0  5  5.0
# 2014-01-04  0.035649  0.846043 -1.813855  1.197930  5.0  5  5.0

# %%
pd.isna(df1)
# Out:
#                 0      1      2      3      A      D      E
# 2014-01-01  False  False  False  False  False  False  False
# 2014-01-02  False  False  False  False   True  False  False
# 2014-01-03  False  False  False  False   True  False   True
# 2014-01-04  False  False  False  False   True  False   True

# %%
cars.mean()
# Out:
# id                      499.500
# rok_produkcji          2009.009
# pojemnosc_silnika      2040.065
# przebieg             132556.677
# cena                  51942.181
# dtype: float64

# %%
cars.apply(np.cumsum)
# Out:
#          id                                              marka  \
# 0         0                                             Nissan
# 1         1                                          NissanBMW
# 2         3                                      NissanBMWOpel
# 3         6                               NissanBMWOpelHyundai
# 4        10                     NissanBMWOpelHyundaiVolkswagen
# ..      ...                                                ...
# 995  495510  NissanBMWOpelHyundaiVolkswagenFiatNissanSeatVo...
# 996  496506  NissanBMWOpelHyundaiVolkswagenFiatNissanSeatVo...
# 997  497503  NissanBMWOpelHyundaiVolkswagenFiatNissanSeatVo...
# 998  498501  NissanBMWOpelHyundaiVolkswagenFiatNissanSeatVo...
# 999  499500  NissanBMWOpelHyundaiVolkswagenFiatNissanSeatVo...
#
#                                                  model  rok_produkcji  \
# 0                                          X-Trail III         2014.0
# ...

# %%
df = pd.DataFrame(np.random.randn(10, 4))
pieces = [df[:3], df[3:7], df[7:]]
pd.concat(pieces)
# Out:
#           0         1         2         3
# 0 -0.784643 -0.287927  1.183049  1.244971
# 1  0.317566 -2.216764  0.567510 -0.229687
# 2 -0.329665  1.221543  1.997644  0.978938
# 3  0.377247 -1.167674  1.521140  0.620693
# 4 -0.097593 -0.234351 -0.973696 -0.515284
# 5 -0.341272 -0.855724  1.177939  0.844578
# 6 -1.298036 -3.094189  1.810246  0.035671
# 7  2.582622 -1.256053  1.034872 -0.138438
# 8  1.815220 -2.100064 -0.027159 -0.338621
# 9  0.286004 -0.187858  1.064390  0.737886

# %%
left = pd.DataFrame({'key': ['foo', 'foo'], 'lval': [1, 2]})
right = pd.DataFrame({'key': ['foo', 'foo'], 'rval': [4, 5]})
pd.merge(left, right, on='key')
# Out:
#    key  lval  rval
# 0  foo     1     4
# 1  foo     1     5
# 2  foo     2     4
# 3  foo     2     5

# %%
df = pd.DataFrame(np.random.randn(8, 4), columns=['A', 'B', 'C', 'D'])
s = df.iloc[3]
df.append(s, ignore_index=True)
# Out:
#           A         B         C         D
# 0 -2.494945 -1.168753  0.048904  0.570030
# 1 -0.256144 -0.479436 -0.710110  1.509341
# 2 -0.588910  0.959872  1.354507  1.216663
# 3  0.227340 -0.075589 -0.084997  0.078916
# 4 -0.571438  0.669559 -0.247359  1.699700
# 5 -0.047092 -1.443219 -0.006638 -0.398235
# 6  1.830749 -1.126397  0.379881  0.162503
# 7 -0.174658 -1.376141  0.319440  0.504911
# 8  0.227340 -0.075589 -0.084997  0.078916

# %%
df = pd.DataFrame({'A': ['foo', 'bar', 'foo', 'bar',
                          'foo', 'bar', 'foo', 'foo'],
                       'B': ['one', 'one', 'two', 'three',
                             'two', 'two', 'one', 'three'],
                       'C': np.random.randn(8),
                       'D': np.random.randn(8)})
print(df)
df.groupby('A').sum()
# Out:
#      A      B         C         D
# 0  foo    one -0.555494  0.311950
# 1  bar    one -1.671709  0.665568
# 2  foo    two -0.195387 -0.845984
# 3  bar  three -1.066414  0.510713
# 4  foo    two  1.261477 -1.973753
# 5  bar    two  1.119020  0.525218
# 6  foo    one  0.172167  1.584305
# 7  foo  three  0.289510  0.154707
#             C         D
# A
# bar -1.619103  1.701499
# foo  0.972273 -0.768774

# %%
df.groupby(['A', 'B']).sum()
# Out:
#                   C         D
# A   B
# bar one   -1.671709  0.665568
#     three -1.066414  0.510713
#     two    1.119020  0.525218
# foo one   -0.383327  1.896255
#     three  0.289510  0.154707
#     two    1.066090 -2.819737

# %%
print("Reshaping")
# Out:
# Reshaping

# %%
tuples = list(zip(*[['bar', 'bar', 'baz', 'baz',
                      'foo', 'foo', 'qux', 'qux'],
                     ['one', 'two', 'one', 'two',
                     'one', 'two', 'one', 'two']]))
index = pd.MultiIndex.from_tuples(tuples, names=['first', 'second'])

df = pd.DataFrame(np.random.randn(8, 2), index=index, columns=['A', 'B'])

df2 = df[:4]

df2
# Out:
#                      A         B
# first second
# bar   one     1.001423  0.735365
#       two    -2.579052  0.298287
# baz   one    -1.331864  0.234127
#       two     2.242029 -0.008658

# %%
stacked = df2.stack()
stacked
# Out:
# first  second
# bar    one     A    1.001423
#                B    0.735365
#        two     A   -2.579052
#                B    0.298287
# baz    one     A   -1.331864
#                B    0.234127
#        two     A    2.242029
#                B   -0.008658
# dtype: float64

# %%
stacked.unstack()
# Out:
#                      A         B
# first second
# bar   one     1.001423  0.735365
#       two    -2.579052  0.298287
# baz   one    -1.331864  0.234127
#       two     2.242029 -0.008658

# %%
stacked.unstack(1)
# Out:
# second        one       two
# first
# bar   A  1.001423 -2.579052
#       B  0.735365  0.298287
# baz   A -1.331864  2.242029
#       B  0.234127 -0.008658

# %%
stacked.unstack(0)
# Out:
# first          bar       baz
# second
# one    A  1.001423 -1.331864
#        B  0.735365  0.234127
# two    A -2.579052  2.242029
#        B  0.298287 -0.008658

# %%
df = pd.DataFrame({'A': ['one', 'one', 'two', 'three'] * 3,
                    'B': ['A', 'B', 'C'] * 4,
                 'C': ['foo', 'foo', 'foo', 'bar', 'bar', 'bar'] * 2,
                   'D': np.random.randn(12),
                    'E': np.random.randn(12)})
df
# Out:
#         A  B    C         D         E
# 0     one  A  foo -0.537678  0.436046
# 1     one  B  foo -0.501074  1.515872
# 2     two  C  foo  0.515740 -0.047530
# 3   three  A  bar  0.393591 -0.049298
# 4     one  B  bar -0.479191  1.201596
# 5     one  C  bar -0.667061 -0.160709
# 6     two  A  foo  0.463724  0.493986
# 7   three  B  foo  0.834502  0.955514
# 8     one  C  foo -0.133146 -0.290965
# 9     one  A  bar -0.815718  0.457435
# 10    two  B  bar  0.672495  1.150235
# 11  three  C  bar -0.144954 -2.002243

# %%
pd.pivot_table(df, values='D', index=['A', 'B'], columns=['C'])
# Out:
# C             bar       foo
# A     B
# one   A -0.815718 -0.537678
#       B -0.479191 -0.501074
#       C -0.667061 -0.133146
# three A  0.393591       NaN
#       B       NaN  0.834502
#       C -0.144954       NaN
# two   A       NaN  0.463724
#       B  0.672495       NaN
#       C       NaN  0.515740

# %%
print("Time series")
# Out:
# Time series

# %%
rng = pd.date_range('1/1/2012', periods=100, freq='S')

ts = pd.Series(np.random.randint(0, 500, len(rng)), index=rng)

ts.resample('5Min').sum()

ts
# Out:
# 2012-01-01 00:00:00    300
# 2012-01-01 00:00:01    194
# 2012-01-01 00:00:02    466
# 2012-01-01 00:00:03     58
# 2012-01-01 00:00:04      8
#                       ...
# 2012-01-01 00:01:35    428
# 2012-01-01 00:01:36    124
# 2012-01-01 00:01:37    422
# 2012-01-01 00:01:38    255
# 2012-01-01 00:01:39    115
# Freq: S, Length: 100, dtype: int32

# %%
rng = pd.date_range('3/6/2012 00:00', periods=5, freq='D')

ts = pd.Series(np.random.randn(len(rng)), rng)

ts
# Out:
# 2012-03-06    0.653668
# 2012-03-07   -0.020020
# 2012-03-08   -0.471985
# 2012-03-09    1.095976
# 2012-03-10   -0.042813
# Freq: D, dtype: float64

# %%
ts_utc = ts.tz_localize('UTC')

ts_utc
# Out:
# 2012-03-06 00:00:00+00:00    0.653668
# 2012-03-07 00:00:00+00:00   -0.020020
# 2012-03-08 00:00:00+00:00   -0.471985
# 2012-03-09 00:00:00+00:00    1.095976
# 2012-03-10 00:00:00+00:00   -0.042813
# Freq: D, dtype: float64

# %%
ts_utc.tz_convert('US/Eastern')
# Out:
# 2012-03-05 19:00:00-05:00    0.653668
# 2012-03-06 19:00:00-05:00   -0.020020
# 2012-03-07 19:00:00-05:00   -0.471985
# 2012-03-08 19:00:00-05:00    1.095976
# 2012-03-09 19:00:00-05:00   -0.042813
# Freq: D, dtype: float64

# %%
rng = pd.date_range('1/1/2012', periods=5, freq='M')

ts = pd.Series(np.random.randn(len(rng)), index=rng)

ts
# Out:
# 2012-01-31    0.012857
# 2012-02-29   -0.101277
# 2012-03-31    0.918425
# 2012-04-30   -0.058054
# 2012-05-31    0.700950
# Freq: M, dtype: float64

# %%
ps = ts.to_period()

ps
# Out:
# 2012-01    0.012857
# 2012-02   -0.101277
# 2012-03    0.918425
# 2012-04   -0.058054
# 2012-05    0.700950
# Freq: M, dtype: float64

# %%
ps.to_timestamp()
# Out:
# 2012-01-01    0.012857
# 2012-02-01   -0.101277
# 2012-03-01    0.918425
# 2012-04-01   -0.058054
# 2012-05-01    0.700950
# Freq: MS, dtype: float64

# %%
prng = pd.period_range('1990Q1', '2000Q4', freq='Q-NOV')

ts = pd.Series(np.random.randn(len(prng)), prng)
    
ts.index = (prng.asfreq('M', 'e') + 1).asfreq('H', 's') + 9

ts.head()
# Out:
# 1990-03-01 09:00    0.112681
# 1990-06-01 09:00    1.539324
# 1990-09-01 09:00   -1.366681
# 1990-12-01 09:00    1.658819
# 1991-03-01 09:00   -0.438858
# Freq: H, dtype: float64

# %%
df = pd.DataFrame({"id": [1, 2, 3, 4, 5, 6],
                       "raw_grade": ['a', 'b', 'b', 'a', 'a', 'e']})

# %%
df["grade"] = df["raw_grade"].astype("category")

df["grade"]
# Out:
# 0    a
# 1    b
# 2    b
# 3    a
# 4    a
# 5    e
# Name: grade, dtype: category
# Categories (3, object): [a, b, e]

# %%
df["grade"].cat.categories = ["very good", "good", "very bad"]

# %%
 df["grade"] = df["grade"].cat.set_categories(["very bad", "bad", "medium",
                                                 "good", "very good"])
    

df["grade"]
# Out:
# 0    very good
# 1         good
# 2         good
# 3    very good
# 4    very good
# 5     very bad
# Name: grade, dtype: category
# Categories (5, object): [very bad, bad, medium, good, very good]

# %%
df.sort_values(by="grade")
# Out:
#    id raw_grade      grade
# 5   6         e   very bad
# 1   2         b       good
# 2   3         b       good
# 0   1         a  very good
# 3   4         a  very good
# 4   5         a  very good

# %%
df.groupby("grade").size()
# Out:
# grade
# very bad     1
# bad          0
# medium       0
# good         2
# very good    3
# dtype: int64

# %%
ts = pd.Series(np.random.randn(1000),
                index=pd.date_range('1/1/2000', periods=1000))
 

ts = ts.cumsum()

ts.plot()

# %%
df = pd.DataFrame(np.random.randn(1000, 4), index=ts.index,
                      columns=['A', 'B', 'C', 'D'])
   

df = df.cumsum()

plt.figure()
df.plot()
plt.legend(loc='best')
